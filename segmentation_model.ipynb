# %% [markdown]
# # Automotive Market Demand & Customer Segmentation Analysis
#
# This notebook performs EDA, Customer Segmentation using K-Means, and Demand Forecasting.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Load Data
df = pd.read_csv('data.csv')
df.head()
# Out:
#    customer_id  age  gender  annual_income region  dealer_visit_count  \
# 0            1   56    Male          70648  South                   9
# 1            2   69    Male         128537   East                   4
# 2            3   46    Male          34516   West                   1
# 3            4   32  Female         137863   East                   8
# 4            5   60    Male         140005   West                   7
#
#    purchase_probability vehicle_preference
# 0                  0.28              Sedan
# 1                  0.48             Luxury
# 2                  0.78          Hatchback
# 3                  0.19                SUV
# 4                  0.35             Luxury

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['annual_income'], bins=30, kde=True)
plt.title('Income Distribution')
plt.show()

# %% [markdown]
# ## 2. Customer Segmentation (K-Means)

# %%
features = ['age', 'annual_income', 'dealer_visit_count', 'purchase_probability']
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df[features])

kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster'] = kmeans.fit_predict(scaled_features)

sns.scatterplot(data=df, x='annual_income', y='purchase_probability', hue='cluster', palette='deep')
plt.title('Customer Segments')
plt.show()
